# %% [markdown]
# An increase in the magnetic field strength is relevant for the efficiency of fusion power experiments.

# %% [markdown]
# Geothermal energy is extracted from the Earth's interior to power a nearby district heating system.

# %% [markdown]
# The petroleum reservoir contains a significant amount of crude oil, which is a fossil energy resource.

# %% [markdown]
# The wind turbine converts the kinetic energy of wind into mechanical energy.

# %% [markdown]
# The photovoltaic power plant generates electric energy using solar radiation.
